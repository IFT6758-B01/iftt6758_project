# %% [markdown]
# ### Simple Visualizations
# This notebook demonstrates how to use the functions in simple visualizations.py to generate plots for Questions 1, 2, and 3.

# %%
import simple_visualization as sv
import pandas as pd

pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# %% [markdown]
# ## Question 1

# %%
# Specify the data folder
data_folder = '../dataset/processed/2022'

# Gather all the data into a single DataFrame
all_data = sv.get_all_data(data_folder)

# Tally the number of shots and goals for each shot type
shot_goal_tally = sv.tally_shots_and_goals(all_data)

# Print the shot goal tally
print(shot_goal_tally)

# Plot the shot types vs goals
sv.plot_shot_types_vs_goals(shot_goal_tally)
# Out:
#        shot_type  shots  goals
# 0       backhand   6918    759
# 1            bat    204     48
# 2   between-legs     53      6
# 3         cradle      2      1
# 4      deflected   1412    241
# 5           poke    425     64
# 6           slap  10080    759
# 7           snap  14317   1708
# 8         tip-in   5674    902
# 9    wrap-around    772     61
# 10         wrist  48086   4428
# /home/aries/6758/iftt6758_project/ift6758/visualizations/simple_visualization.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   season_data = pd.concat(all_data, ignore_index=True)

# %% [markdown]
# ## Question 2

# %%
# Specify the data folders
data_folders = ['../dataset/processed/2018', '../dataset/processed/2019', '../dataset/processed/2020']

for folder in data_folders:
    # Process all the distances for the games
    distance_data = sv.process_all_games(folder)

    # Plot the shot outcomes by distance
    sv.plot_shot_outcomes_by_distance(distance_data)
# Out:
# /home/aries/6758/iftt6758_project/ift6758/visualizations/simple_visualization.py:220: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   distance_data = distill_data.groupby('distance_bin').agg(
# /home/aries/6758/iftt6758_project/ift6758/visualizations/simple_visualization.py:220: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   distance_data = distill_data.groupby('distance_bin').agg(
# /home/aries/6758/iftt6758_project/ift6758/visualizations/simple_visualization.py:220: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   distance_data = distill_data.groupby('distance_bin').agg(

# %% [markdown]
# ## Question 3

# %%
# Process all the distances for all the games
distance_data = sv.process_all_games(data_folder) # 2022

# Take the distance data and segment it between shot types
pivot_table = sv.prepare_goal_percentage_data(distance_data)

# Plot the heatmap
sv.plot_goal_percentage_heatmap(pivot_table)
# Out:
# /home/aries/6758/iftt6758_project/ift6758/visualizations/simple_visualization.py:263: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = shots_data.groupby(['shot_type', 'distance_bin']).agg(
